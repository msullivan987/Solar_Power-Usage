# %%
import pandas as pd
import os

# %%
csv_path = "1990-2019_annual_GENERATION_state.csv"

# %%
df = pd.read_csv(csv_path,header=None)
df = df.rename(columns=df.iloc[1])
df.columns
df = df[["YEAR","STATE","TYPE OF PRODUCER","ENERGY SOURCE","GENERATION (Megawatthours)"]]
df = df.drop(df.index[[0,1]])
df = df.reset_index()

# %%
df.head(15)
# Out:
#     index  YEAR STATE                           TYPE OF PRODUCER  \
# 0       2  1990    AK              Total Electric Power Industry
# 1       3  1990    AK              Total Electric Power Industry
# 2       4  1990    AK              Total Electric Power Industry
# 3       5  1990    AK              Total Electric Power Industry
# 4       6  1990    AK              Total Electric Power Industry
# 5       7  1990    AK              Total Electric Power Industry
# 6       8  1990    AK              Total Electric Power Industry
# 7       9  1990    AK    Electric Generators, Electric Utilities
# 8      10  1990    AK    Electric Generators, Electric Utilities
# 9      11  1990    AK    Electric Generators, Electric Utilities
# 10     12  1990    AK    Electric Generators, Electric Utilities
# 11     13  1990    AK    Electric Generators, Electric Utilities
# 12     14  1990    AK    Electric Generators, Electric Utilities
# 13     15  1990    AK  Combined Heat and Power, Industrial Power
# 14     16  1990    AK  Combined Heat and Power, Industrial Power
#
#                   ENERGY SOURCE GENERATION (Megawatthours)
# 0                         Total                  5,599,506
# 1                          Coal                    510,573
# 2    Hydroelectric Conventional                    974,521
# 3                   Natural Gas                  3,466,261
# 4                     Petroleum                    497,116
# 5                          Wind                          0
# 6   Wood and Wood Derived Fuels                    151,035
# 7                         Total                  4,493,024
# 8                          Coal                    311,960
# 9    Hydroelectric Conventional                    974,521
# 10                  Natural Gas                  2,869,638
# 11                    Petroleum                    336,905
# 12                         Wind                          0
# 13                        Total                    840,949
# 14                  Natural Gas                    596,623
